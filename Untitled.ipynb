# %%
import gymnasium
import underwater_env
env = gymnasium.make('underwater_env/Underwater-v0')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import gymnasium
# ----> 2 import underwater_env
#       3 env = gymnasium.make('underwater_env/Underwater-v0')
#
# ModuleNotFoundError: No module named 'underwater_env'
